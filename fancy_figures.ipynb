# %%
#%matplotlib notebook
from bundle_adjust import ba_figures

# Display and interface settings (just for the notebook interface)
# %load_ext autoreload
# %autoreload 2
np.set_printoptions(linewidth=150)

# %%
ba_figures.plot_softl1_vs_linear_loss()

# %%
ba_figures.plot_teaser_rpc_fitting()

# %%
ba_figures.display_skysat_sensor_scheme()

# %%
ba_figures.display_skysat_acquisition_scheme()
# Out:
# /home/rogermm14/sat-bundleadjust/bundle_adjust/ba_figures.py:92: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   linewidth=1, edgecolor='k', color='k', fill=True, alpha=0.15, zorder=2)
